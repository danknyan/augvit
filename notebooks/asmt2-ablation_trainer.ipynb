# %% [markdown]
# # Setup

# %% [markdown]
# ## Runtime Estimatation

# %% [markdown]
# ## Imports

# %%
# ops
from time import time
# warnings
import warnings
# visualization
# deep learning libs
import torch
from PDD_training import train_and_store
from PDD_helpers import get_train_val_test_datasets, plot_training, show_lb,plot_cm, show_predictions
from PDD_helpers import ViTConfig as VTC
from PDD_data_mgmt import CropDiseaseDataset,PreBatchedDataset 
from torch.utils.data import DataLoader
# data mgmt
from dataclasses import asdict, dataclass

# %%
start_run_time = time()

# %% [markdown]
# ## Random Seed

# %%
torch.manual_seed(42)

# %% [markdown]
# ## CUDA

# %%
# warn user if CPU
use_cuda = True if torch.cuda.is_available() else False
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(torch.cuda.get_device_name(0)) if use_cuda else warnings.warn('We are using CPU.')
torch.cuda.set_device(0)  # force correct GPU
device = torch.device("cuda:0")
# Out:
# NVIDIA GeForce RTX 3080 Ti Laptop GPU

# %% [markdown]
# # Hyperparameter Storage Class

# %%
@dataclass
class BestViTConfig:
    batch_alias: str 
    # architecture
    patch_size: int        = 16
    embedding_dim: int     = 512
    depth: int             = 6
    heads: int             = 12
    attn_head_dim: int     = 64
    ffn_inner_dim: int     = 1024
    head_hidden_dim: int   = 256
    # regularization
    emb_dropout: float     = 0.0
    attn_dropout: float    = 0.1
    ffn_dropout: float     = 0.1
    head_dropout: float    = 0.1
    decay: float           = 1e-6
    # optimization
    opt: str               = "adamw"
    lr: float              = 1e-4
    scheduler: bool        = True
    train_aug: str         = "flipmix"
    loss: str              = "focal"
    # training
    epochs: int            = 75
    n_runs: int            = 1

# %% [markdown]
# # Load

# %% [markdown]
# ## Load Images to Dataset

# %%
dataset = CropDiseaseDataset(
    root = "./FieldPlant_augmented_tensor",
)
num_classes = len(dataset.class_names)

# %% [markdown]
# # Train-Val-Test Split

# %%
train_dataset,val_dataset,test_dataset = get_train_val_test_datasets(dataset, train_p = 0.8,)

# %% [markdown]
# ## Data Loaders

# %%
batch_size = 256
test_loader = DataLoader(test_dataset,
                                   batch_size=batch_size, 
                                   num_workers=6,
                                   shuffle= False)

# %%
train_prebatch = PreBatchedDataset(train_dataset,
                                   batch_size=batch_size, 
                                   shuffle= True)
val_prebatch = PreBatchedDataset(val_dataset,
                                   batch_size=batch_size, 
                                   shuffle= False)

# %% [markdown]
# ## Results Logging

# %%
training_log = []

# %% [markdown]
# # Experiments

# %% [markdown]
# ## Zero DO Flip vs Flipmix

# %%
if __name__ == '__main__':
    for train_aug in ["flip","flipmix"]:
        config = BestViTConfig(batch_alias="0.1_DO_Aug",
                                patch_size= 28,
                                train_aug=train_aug,
                                attn_dropout = 0.1,
                                ffn_dropout =0.1,
                                head_dropout= 0.1,
                                n_runs=3)
        train_and_store(**asdict(config),
                        train_loader=train_prebatch,
                        val_loader=val_prebatch, 
                        training_log=training_log,
                        save_model=True
                        )
# Out:
# [0.1_DO_Aug] run 1/3 — A=12x64 T=6x1024 H=256 patch=28 aug=flip do_e,a,t,h=0.0,0.1,0.1,0.1 opt=adamw lr=0.0001 wd=1e-06 sched=cosine
# Training Epoch:  65%|██████▌   | 49/75 [08:20<04:25, 10.21s/it]
# Early stopping triggered at epoch 50
#
# [0.1_DO_Aug] run 2/3 — A=12x64 T=6x1024 H=256 patch=28 aug=flip do_e,a,t,h=0.0,0.1,0.1,0.1 opt=adamw lr=0.0001 wd=1e-06 sched=cosine
# Training Epoch:  65%|██████▌   | 49/75 [08:46<04:39, 10.75s/it]
# Early stopping triggered at epoch 50
#
# [0.1_DO_Aug] run 3/3 — A=12x64 T=6x1024 H=256 patch=28 aug=flip do_e,a,t,h=0.0,0.1,0.1,0.1 opt=adamw lr=0.0001 wd=1e-06 sched=cosine
# Training Epoch:  92%|█████████▏| 69/75 [12:41<01:06, 11.03s/it]
# Early stopping triggered at epoch 70
#
#   [0.1_DO_Aug] A=12x64 T=6x1024 H=256 patch=28 aug=flip do_e,a,t,h=0.0,0.1,0.1,0.1 opt=adamw lr=0.0001 wd=1e-06 sched=cosine
#   val F1 across 3 runs: ['0.9039', '0.8936', '0.9091']  F1 mean=0.9022 Acc mean=0.9035 12m41s
# model saved to ./models/A=12x64 T=6x1024 H=256 patch=28 aug=flip do_e,a,t,h=0.0,0.1,0.1,0.1 opt=adamw lr=0.0001 wd=1e-06 sched=cosine_best.pth
#
# [0.1_DO_Aug] run 1/3 — A=12x64 T=6x1024 H=256 patch=28 aug=flipmix do_e,a,t,h=0.0,0.1,0.1,0.1 opt=adamw lr=0.0001 wd=1e-06 sched=cosine
# Training Epoch: 100%|██████████| 75/75 [13:55<00:00, 11.15s/it]
# [0.1_DO_Aug] run 2/3 — A=12x64 T=6x1024 H=256 patch=28 aug=flipmix do_e,a,t,h=0.0,0.1,0.1,0.1 opt=adamw lr=0.0001 wd=1e-06 sched=cosine
# Training Epoch:  88%|████████▊ | 66/75 [12:29<01:42, 11.36s/it]
# Early stopping triggered at epoch 67
#
# [0.1_DO_Aug] run 3/3 — A=12x64 T=6x1024 H=256 patch=28 aug=flipmix do_e,a,t,h=0.0,0.1,0.1,0.1 opt=adamw lr=0.0001 wd=1e-06 sched=cosine
# Training Epoch: 100%|██████████| 75/75 [13:58<00:00, 11.18s/it]
#   [0.1_DO_Aug] A=12x64 T=6x1024 H=256 patch=28 aug=flipmix do_e,a,t,h=0.0,0.1,0.1,0.1 opt=adamw lr=0.0001 wd=1e-06 sched=cosine
#   val F1 across 3 runs: ['0.8968', '0.9031', '0.9087']  F1 mean=0.9029 Acc mean=0.9044 13m59s
# model saved to ./models/A=12x64 T=6x1024 H=256 patch=28 aug=flipmix do_e,a,t,h=0.0,0.1,0.1,0.1 opt=adamw lr=0.0001 wd=1e-06 sched=cosine_best.pth

# %%
plot_training("0.1_DO_Aug", training_log)

# %%
show_lb(training_log)
# Out:
# <style type="text/css">
# #T_38fe5 th {
#   text-align: left;
#   font-weight: 500;
# }
# #T_38fe5 caption {
#   font-weight: 500;
#   font-size: 14px;
#   text-align: left;
#   padding-bottom: 8px;
# }
# #T_38fe5_row0_col0, #T_38fe5_row0_col1, #T_38fe5_row0_col3, #T_38fe5_row0_col4, #T_38fe5_row0_col5, #T_38fe5_row0_col6, #T_38fe5_row1_col0, #T_38fe5_row1_col1, #T_38fe5_row1_col3, #T_38fe5_row1_col4, #T_38fe5_row1_col5, #T_38fe5_row1_col6 {
#   text-align: left;
# }
# #T_38fe5_row0_col2 {
#   background-color: #004529;
#   color: #f1f1f1;
#   text-align: left;
# }
# #T_38fe5_row1_col2 {
#   background-color: #ffffe5;
#   color: #000000;
#   text-align: left;
# }
# </style>
# <table id="T_38fe5">
#   <caption>Leaderboard — ranked by val F1</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_38fe5_level0_col0" class="col_heading level0 col0" >config</th>
#       <th id="T_38fe5_level0_col1" class="col_heading level0 col1" >runs</th>
#       <th id="T_38fe5_level0_col2" class="col_heading level0 col2" >f1 (mean)</th>
#       <th id="T_38fe5_level0_col3" class="col_heading level0 col3" >acc (mean)</th>
#       <th id="T_38fe5_level0_col4" class="col_heading level0 col4" >loss (mean)</th>
#       <th id="T_38fe5_level0_col5" class="col_heading level0 col5" >epochs (mean)</th>
#       <th id="T_38fe5_level0_col6" class="col_heading level0 col6" >training time (mean)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_38fe5_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_38fe5_row0_col0" class="data row0 col0" >A=12x64 T=6x1024 H=256 patch=28 aug=flipmix do_e,a,t,h=0.0,0.1,0.1,0.1 opt=adamw lr=0.0001 wd=1e-06 sched=cosine</td>
#       <td id="T_38fe5_row0_col1" class="data row0 col1" >3</td>
#       <td id="T_38fe5_row0_col2" class="data row0 col2" >0.9029</td>
#       <td id="T_38fe5_row0_col3" class="data row0 col3" >0.9044</td>
#       <td id="T_38fe5_row0_col4" class="data row0 col4" >0.1850</td>
#       <td id="T_38fe5_row0_col5" class="data row0 col5" >72.3</td>
#       <td id="T_38fe5_row0_col6" class="data row0 col6" >808.2</td>
#     </tr>
#     <tr>
#       <th id="T_38fe5_level0_row1" class="row_heading level0 row1" >2</th>
#       <td id="T_38fe5_row1_col0" class="data row1 col0" >A=12x64 T=6x1024 H=256 patch=28 aug=flip do_e,a,t,h=0.0,0.1,0.1,0.1 opt=adamw lr=0.0001 wd=1e-06 sched=cosine</td>
#       <td id="T_38fe5_row1_col1" class="data row1 col1" >3</td>
#       <td id="T_38fe5_row1_col2" class="data row1 col2" >0.9022</td>
#       <td id="T_38fe5_row1_col3" class="data row1 col3" >0.9035</td>
#       <td id="T_38fe5_row1_col4" class="data row1 col4" >0.1549</td>
#       <td id="T_38fe5_row1_col5" class="data row1 col5" >56.7</td>
#       <td id="T_38fe5_row1_col6" class="data row1 col6" >596.2</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# # Inspect Predictions

# %%
from PDD_ViT import VisionTransformer
state_dict_path = "./models/A=12x64 T=6x1024 H=256 patch=28 aug=flipmix do_e,a,t,h=0.0,0.1,0.1,0.1 opt=adamw lr=0.0001 wd=1e-06 sched=cosine_best.pth"
best_model = VisionTransformer(patch_size= 28, embedding_dim= 512, depth= 6, heads= 12, attn_head_dim= 64, ffn_inner_dim= 1024, head_hidden_dim= 256, emb_dropout= 0.0, attn_dropout= 0.1, ffn_dropout= 0.1, head_dropout= 0.1)
state_dict = torch.load(state_dict_path)
best_model.load_state_dict(state_dict)
best_model = best_model.to("cuda")

# %%
plot_cm(best_model,test_loader)
# Out:
# ACC: 0.8984
#  F1-W] 0.8953

# %%
show_predictions(best_model, test_dataset.dataset, n=8, cols=4)

# %% [markdown]
# ### Runtime

# %%
print(f"Total runtime is {(time() - start_run_time)/60} minutes.")
# Out:
# Total runtime is 72.13007009029388 minutes.
